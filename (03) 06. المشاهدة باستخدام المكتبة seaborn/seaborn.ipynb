# %%
import pandas as pd

df = pd.read_csv('nba.csv')

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    int64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB
# None

# %%
import seaborn as sns

sns.lineplot(data=df, x='Age', y='Weight')
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.lineplot(data=df, x='Age', y='Weight', hue=df['Position'])
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.scatterplot(data=df, x='Age', y='Weight')
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.scatterplot(data=df, x='Age', y='Weight', hue=df['Position'])
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.boxplot(data=df, x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(data=df, x='Age', y='Weight')
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.boxplot(data=df, x='Age', y='Height')
# Out:
# <Axes: xlabel='Age', ylabel='Height'>

# %%
sns.barplot(data=df, x='Age', y='Weight')
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.countplot(data=df, x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='count'>
